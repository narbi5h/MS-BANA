# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# importing pandas library
df = pd.read_csv('DJIA.csv') # here we are importing the csv file
print(df)
#print(df.head()) # print out the first 5 lines of sample file
# Out:
#         Month Closing Value Percentage Change  Unnamed: 3  Unnamed: 4
# 0      Jan-50        201.79               NaN         NaN         NaN
# 1      Feb-50        203.44             0.82%         NaN         NaN
# 2      Mar-50        206.05             1.28%         NaN         NaN
# 3      Apr-50        213.56             3.64%         NaN         NaN
# 4      May-50        223.42             4.62%         NaN         NaN
# ...       ...           ...               ...         ...         ...
# 11092     NaN           NaN               NaN         NaN         NaN
# 11093     NaN           NaN               NaN         NaN         NaN
# 11094     NaN           NaN               NaN         NaN         NaN
# 11095     NaN           NaN               NaN         NaN         NaN
# 11096     NaN           NaN               NaN         NaN         NaN
#
# [11097 rows x 5 columns]

# %%
#df=df.dropna(axis=1, how='all',inplace=True)
df = df.dropna(axis=1, how='all')
df = df.dropna(axis=0, how='all')

# %%
df = df.applymap(lambda x: x.replace(',', '') if isinstance(x, str) else x)
df = df.applymap(lambda y: y.replace('%', '') if isinstance(y, str) else y)
# Out:
# C:\Users\gio12\AppData\Local\Temp\ipykernel_31060\3173380208.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.replace(',', '') if isinstance(x, str) else x)
# C:\Users\gio12\AppData\Local\Temp\ipykernel_31060\3173380208.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda y: y.replace('%', '') if isinstance(y, str) else y)

# %%
df.describe()
# Out:
#          Month Closing Value Percentage Change
# count      820           820               819
# unique     820           819               616
# top     Apr-18        269.23             -1.47
# freq         1             2                 5

# %%
df['Percentage Change'] = df['Percentage Change'].astype(float)

# %%
plt.figure(figsize=(13, 7))
xticks = range(0, len(df),30)
plt.xticks(xticks, df['Month'].iloc[xticks], rotation=45, ha='right', fontsize=12)
sns.lineplot(data=df, x="Month", y="Percentage Change")
plt.title('Percentage Change in DJIA over time', fontsize=15)
plt.tight_layout()
